# %%
# %matplotlib inline

# %%
pip install wordcloud
# Out:
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/00/09/abb305dce85911b8fba382926cfc57f2f257729e25937fdcc63f3a1a67f9/wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/299.9 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/299.9 kB 660.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 122.9/299.9 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 299.9/299.9 kB 3.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Masked wordcloud
#
# Using a mask you can generate wordclouds in arbitrary shapes.

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, 'perth.txt')).read()

# read the mask image
perth_mask = np.array(Image.open(path.join(d, "perth_mask.png")))

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=perth_mask,
               stopwords=stopwords, contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "perth.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(perth_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()
